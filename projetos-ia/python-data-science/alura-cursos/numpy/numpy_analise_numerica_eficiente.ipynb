# %%
# Pegando o dataset do github manualmente
import numpy as np

url = "dados/apples_ts.csv"

# Estamos carregando o arquivo de formato texto, com delimitador de vírgula e pulando a primeira coluna
dataframe = np.loadtxt(url, delimiter=",", usecols=np.arange(1, 88, 1))
dataframe
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
# Verifica a quantidade de dimensões do dataframe
dataframe.ndim
# Out:
# 2

# %%
# Verifica a quantidade de elementos do dataframe
dataframe.size
# Out:
# 522

# %%
# Seria o formato do dataframe, ou seja, a quantidade de linhas e colunas
dataframe.shape
# Out:
# (6, 87)

# %%
# Realiza uma transposição do dataframe, nesse caso a primeira coluna é representa as datas e as demais colunas os valores vendidos de maçãs de cada cidade
dataframe.T
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,  66.06  ,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %%
# Podemos salvar o dados transporto em uma variável
dados_transpostos = dataframe.T
dados_transpostos.shape

datas = dados_transpostos[:, 0]
precos = dados_transpostos[:,1:6]

# %%
datas = np.arange(1,88,1)

# %%
import matplotlib.pyplot as plt

plt.plot(datas, precos[:,0])

# %%
moscou = precos[:,0]
kaliningrad = precos[:,1]
oeterburgo = precos[:,2]
krasnodar = precos[:,3]
ekaterinburg = precos[:,4]

# %%
moscou.shape
# Out:
# (87,)

# %%
moscou_ano1 = moscou[0:12]
moscou_ano2 = moscou[12:24]
moscou_ano3 = moscou[24:36]
moscou_ano4 = moscou[36:48]

# %%
plt.plot(np.arange(1,13,1), moscou_ano1)
plt.plot(np.arange(1,13,1), moscou_ano2)
plt.plot(np.arange(1,13,1), moscou_ano3)
plt.plot(np.arange(1,13,1), moscou_ano4)
plt.legend(["Ano 1", "Ano 2", "Ano 3", "Ano 4"])

# %%
np.array_equal(moscou_ano1, moscou_ano2)
# Out:
# False

# %%
np.allclose(moscou_ano1, moscou_ano2, 10)
# Out:
# True

# %%
plt.plot(datas, kaliningrad)

# %%
kaliningrad
# NaN = Not a Number
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
np.isnan(kaliningrad)

sum(np.isnan(kaliningrad))
# Out:
# np.int64(1)

# %%
# Podemos tratar o valor NaN, usando a média do numero anterior e posterior
kaliningrad[4] = np.mean([kaliningrad[3], kaliningrad[5]])

# %%
np.mean(moscou)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(kaliningrad)
# Out:
# np.float64(74.5506896551724)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Carregar dados (ignorando a primeira linha = cabeçalho)
dados = np.loadtxt('dados_frutas.csv', delimiter=',', skiprows=1)  # ← skiprows=1 adicionado

# 2. Separar laranjas (linhas 0-4999) e toranjas (linhas 5000-9999)
laranjas = dados[:5000]
toranjas = dados[5000:]

# 3. Extrair características
diametro_laranjas = laranjas[:, 0]
peso_laranjas = laranjas[:, 1]

diametro_toranjas = toranjas[:, 0]
peso_toranjas = toranjas[:, 1]

# 4. Plotar
plt.figure(figsize=(12, 7))

plt.scatter(diametro_laranjas, peso_laranjas, c='orange', alpha=0.6, label='Laranjas', edgecolors='w')
plt.scatter(diametro_toranjas, peso_toranjas, c='purple', alpha=0.6, label='Toranjas', edgecolors='w')

plt.title('Distribuição de Diâmetro vs Peso de Frutas', fontsize=14)
plt.xlabel('Diâmetro (cm)', fontsize=12)
plt.ylabel('Peso (g)', fontsize=12)
plt.grid(linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[47], line 5
#       2 import matplotlib.pyplot as plt
#       4 # 1. Carregar dados (ignorando a primeira linha = cabeçalho)
# ----> 5 dados = np.loadtxt('dados_frutas.csv', delimiter=',', skiprows=1)  # ← skiprows=1 adicionado
#       7 # 2. Separar laranjas (linhas 0-4999) e toranjas (linhas 5000-9999)
#       8 laranjas = dados[:5000]
#
# File c:\Users\a914686\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\lib\_npyio_impl.py:1397, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1394 if isinstance(delimiter, bytes):
#    1395     delimiter = delimiter.decode('latin1')
# -> 1397 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
# ...

# %%
plt.plot(datas, moscou)

# %%
# Ajusta uma reta aos dados

# y = ax+b, onde a é o coeficiente angular e b é o coeficiente linear

x = datas
y = 2 * x + 80

plt.plot(datas, moscou)
plt.plot(x, y)

# %%
# Precisamos normalizar a reta

# Difereça entre os valores de y e preço
(moscou-y)

# Eleva ao quadrado para não ter valores negativos
np.power(moscou-y, 2)

# Soma todos os valores para que tenhamos um único valor
np.sum(np.power(moscou-y, 2))

# Por fim, extrairemos a raiz quadrada da soma
np.sqrt(np.sum(np.power(moscou-y, 2)))
# Out:
# np.float64(749.2329171225728)

# %%
# Escolheremos valores aletaórios para a e b para ajustar a reta
y = 0.52 * x + 80

plt.plot(datas, moscou)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(moscou-y, 2)))
# Out:
# np.float64(110.48504740461489)

# %%
# Ou podemos utilizar a função linalg.norm da biblioteca numpy
np.linalg.norm(moscou-y)
# Out:
# np.float64(110.4850474046149)

# %%
# Podemos por meio de uma fórmula, estimar o valor de a (Coeficiente angular), dessa forma não precisamos mais escolher valores aleatórios

# a = Coeficiente angular
# n = Número de elementos
# Y = Preços (no nosso caso da cidade de Moscou)
# X = Datast (no nosso caso os dias)

# a = (n*Σ(X*Y) - Σ(X)Σ(Y)) / n*Σ(X²) - (Σ(X)²)
# b = (Σ(Y) - a*Σ(X)) / n

# Em termos leigos temos:
# a = n * Soma(X * Y) - Soma(X) * Soma(Y) / n * Soma(X²) - (Soma(X))²

Y = moscou
X = datas
n = np.size(moscou)

a = (n * np.sum(X * Y) - np.sum(X) * np.sum(Y)) / (n * np.sum(X**2) - np.sum(X)**2)
b = (np.sum(Y) - a * np.sum(X)) / n
a, b
# Out:
# (np.float64(0.43520212145512926), np.float64(79.64892274792834))

# %%
y = a * X + b

np.linalg.norm(moscou-y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(datas, moscou)
plt.plot(x, y)

# %%
# Atividade

# Desenhar um semi-circulo com a seguinte fórmula: y = sqrt(1 - x²)

# Gerar uma sequência de valores de x de -1 a 1
x1 = np.arange(-1, 1.01, 0.00001)

# Implementar a fórmula do semi-circulo, mas para desenhar o círculo completo, precisamos de duas fórmulas
y1 = np.sqrt(1 - x1**2)
y2 = -np.sqrt(1 - x1**2)

# Plotar o gráfico com as duas partes do semi-circulo
plt.plot(x1, y1, 'r')
plt.plot(x1, y2, 'r')

# Adicionar um título ao gráfico e aos rótulos dos eixos x e y
plt.title('Círculo', fontsize=14)
plt.xlabel('Eixo x', fontsize=12)
plt.ylabel('Eixo y', fontsize=12)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\a914686\AppData\Local\Temp\ipykernel_20128\3355987711.py:9: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(1 - x1**2)
# C:\Users\a914686\AppData\Local\Temp\ipykernel_20128\3355987711.py:10: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -np.sqrt(1 - x1**2)

# %%
# Gerar valores de x de -1 a 1 com alta resolução
x1 = np.linspace(-1, 1, 10000)  # Usar linspace para garantir simetria

# Calcular os semi-círculos
y_superior = np.sqrt(1 - x1**2)
y_inferior = -np.sqrt(1 - x1**2)

# Configurar o gráfico
plt.figure(figsize=(6, 6))  # Figura quadrada

# Plotar ambos os semi-círculos
plt.plot(x1, y_superior, 'r', linewidth=2)
plt.plot(x1, y_inferior, 'r', linewidth=2)

# Forçar proporção igual entre os eixos (chave para o círculo perfeito)
plt.axis('equal')  # <--- Isso corrige a distorção!

# Adicionar labels e título
plt.title('Círculo Perfeito', fontsize=14)
plt.xlabel('Eixo x', fontsize=12)
plt.ylabel('Eixo y', fontsize=12)

# Mostrar o gráfico
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
plt.plot(datas, moscou)
plt.plot(x, y)
plt.plot(41.5, 41.5 * a + b, '*r')
plt.plot(100, 100 * a + b, '*r')

# %%
import numpy as np
import matplotlib.pyplot as plt

# Carregar dados (ignorando cabeçalho)
dados = np.loadtxt('dados/dados_frutas.csv', delimiter=',', skiprows=1)

# Separar laranjas e toranjas
laranjas = dados[:5000]
toranjas = dados[5000:]

def calcular_coeficientes(x, y):
    """Calcula m (coef. angular) e b (coef. linear) via mínimos quadrados."""
    x_medio = np.mean(x)
    y_medio = np.mean(y)
    
    # Numerador e denominador da fórmula de m
    numerador = np.sum((x - x_medio) * (y - y_medio))
    denominador = np.sum((x - x_medio) ** 2)
    
    m = numerador / denominador
    b = y_medio - m * x_medio
    return m, b

# Coeficientes para laranjas
x_laranjas = laranjas[:, 0]
y_laranjas = laranjas[:, 1]
m_laranjas, b_laranjas = calcular_coeficientes(x_laranjas, y_laranjas)

# Coeficientes para toranjas
x_toranjas = toranjas[:, 0]
y_toranjas = toranjas[:, 1]
m_toranjas, b_toranjas = calcular_coeficientes(x_toranjas, y_toranjas)

# Resultados
print("Laranjas:")
print(f"Coeficiente angular (m): {m_laranjas:.2f}")
print(f"Coeficiente linear (b): {b_laranjas:.2f}\n")

print("Toranjas:")
print(f"Coeficiente angular (m): {m_toranjas:.2f}")
print(f"Coeficiente linear (b): {b_toranjas:.2f}")

# Plotar os dados e as retas de regressão
plt.figure(figsize=(12, 7))

# Laranjas
plt.scatter(x_laranjas, y_laranjas, c='orange', alpha=0.5, label='Laranjas')
plt.plot(x_laranjas, m_laranjas * x_laranjas + b_laranjas, 
         '--', color='darkorange', linewidth=2, label='Regressão Laranjas')

# Toranjas
plt.scatter(x_toranjas, y_toranjas, c='purple', alpha=0.5, label='Toranjas')
plt.plot(x_toranjas, m_toranjas * x_toranjas + b_toranjas, 
         '--', color='indigo', linewidth=2, label='Regressão Toranjas')

plt.title('Reta de Regressão por Fruta', fontsize=14)
plt.xlabel('Diâmetro (cm)', fontsize=12)
plt.ylabel('Peso (g)', fontsize=12)
plt.legend()
plt.grid(linestyle='--', alpha=0.5)
plt.show()
# Out:
# Laranjas:
# Coeficiente angular (m): -0.09
# Coeficiente linear (b): 150.49
#
# Toranjas:
# Coeficiente angular (m): 0.62
# Coeficiente linear (b): 342.07

# %%
# Gera numeros aleatórios
np.random.randint(low = 40, high = 100, size = 100)
# Out:
# array([59, 44, 42, 95, 49, 44, 97, 51, 78, 54, 74, 69, 98, 59, 97, 55, 73,
#        75, 56, 89, 87, 59, 45, 79, 42, 41, 79, 86, 87, 89, 43, 78, 76, 89,
#        57, 92, 57, 67, 93, 74, 82, 74, 81, 65, 55, 75, 84, 40, 65, 64, 65,
#        69, 83, 87, 63, 62, 51, 61, 82, 50, 78, 83, 55, 53, 62, 61, 78, 98,
#        86, 91, 82, 46, 64, 55, 54, 99, 99, 55, 97, 82, 57, 86, 95, 74, 44,
#        56, 46, 44, 68, 90, 59, 71, 88, 91, 45, 72, 79, 44, 79, 84],
#       dtype=int32)

# %%
coef_angulares = np.random.uniform(low = 0.10, high = 0.90, size = 100)
coef_angulares
# Out:
# array([0.57432183, 0.12911268, 0.42957256, 0.21890864, 0.3373303 ,
#        0.85634265, 0.14788957, 0.61647573, 0.33424334, 0.86205857,
#        0.57542538, 0.80273603, 0.30092198, 0.47235203, 0.5015076 ,
#        0.15317354, 0.23628825, 0.35528465, 0.85338871, 0.47948459,
#        0.60057876, 0.35540066, 0.30402357, 0.29705883, 0.85402618,
#        0.77929448, 0.82295923, 0.3443356 , 0.51449151, 0.33353642,
#        0.58429505, 0.37167305, 0.69850769, 0.33215257, 0.26114166,
#        0.41260939, 0.19076439, 0.58594317, 0.1904117 , 0.51787592,
#        0.54060865, 0.69780605, 0.51539852, 0.23079673, 0.44436526,
#        0.84330111, 0.43248796, 0.25297976, 0.5676585 , 0.17180291,
#        0.52160265, 0.8167956 , 0.14506175, 0.11414365, 0.76981377,
#        0.8305591 , 0.55354178, 0.39095163, 0.34604421, 0.46526823,
#        0.36640944, 0.87114332, 0.4909424 , 0.28170221, 0.88572484,
#        0.23395129, 0.5999138 , 0.1155662 , 0.64195191, 0.80185665,
# ...

# %%
norma = np.array([])
for i in range(100):
    norma = np.append(norma, np.linalg.norm(moscou - (coef_angulares[i] * X + b)))
# Out:
# array([121.17934383, 176.87216874, 101.83170758, 144.25406283,
#        111.81049497, 223.53291025, 169.69295788, 133.04241873,
#        112.42172522, 225.94095504, 121.46303896, 201.31131438,
#        119.9540614 , 103.29956308, 106.50981052, 167.70190584,
#        138.55637978, 108.57620675, 222.29108872, 103.92544028,
#        128.33451713, 108.55715185, 119.18525107, 120.92965236,
#        222.55892655, 191.83649068, 209.61159195, 110.48233553,
#        108.4733318 , 112.56389126, 123.79938882, 106.13126688,
#        160.76059444, 112.84453578, 130.87379364, 102.35525991,
#        153.96347213, 124.24425749, 154.08854883, 109.03607588,
#        113.32961887, 160.50411779, 108.62212152, 140.3297665 ,
#        101.88900233, 218.06437263, 101.80503337, 133.33151923,
#        119.50041743, 160.79484784, 109.67937681, 207.07035741,
#        170.76397382, 182.70210119, 188.0542336 , 212.75808725,
#        116.14548779, 103.92239888, 110.1710553 , 102.78363936,
# ...

# %%
coef_angulares[np.argmin(norma)]
# Out:
# np.float64(0.437438903536466)

# %%
np.random.seed(84)
coef_angulares = np.random.uniform(low = 0.10, high = 0.90, size = 100)
norma = np.array([])
for i in range(100):
    norma = np.append(norma, np.linalg.norm(moscou - (coef_angulares[i] * X + b)))

coef_angulares[np.argmin(norma)]
# Out:
# np.float64(0.43471917334609456)

# %%
dados_salvos = np.column_stack([norma, coef_angulares])
np.savetxt('dados/dados_salvos.csv', dados_salvos, delimiter=',', header='Norma,Coeficiente Angular', comments='')

# %%
# Carregar dados (ignorando cabeçalho)
dados = np.loadtxt('dados_frutas.csv', delimiter=',', skiprows=1)

# Separar laranjas (0-4999) e toranjas (5000-9999)
laranjas = dados[:5000]
toranjas = dados[5000:]

def calcular_m(x, y, b):
    """Calcula o coeficiente angular (m) dado um b fixo."""
    numerador = np.sum(x * (y - b))
    denominador = np.sum(x ** 2)
    return numerador / denominador

# Coeficiente angular para laranjas (b = 17)
x_laranjas = laranjas[:, 0]
y_laranjas = laranjas[:, 1]
m_laranjas = calcular_m(x_laranjas, y_laranjas, b=17)

# Coeficiente angular para toranjas (b = 17)
x_toranjas = toranjas[:, 0]
y_toranjas = toranjas[:, 1]
m_toranjas = calcular_m(x_toranjas, y_toranjas, b=17)

# Resultados
print("Laranjas:")
print(f"Coeficiente angular (m) com b=17: {m_laranjas:.2f}\n")

print("Toranjas:")
print(f"Coeficiente angular (m) com b=17: {m_toranjas:.2f}")

# Exemplo com 3 laranjas (b=17)
x = np.array([7.0, 7.5, 8.0])
y = np.array([150, 165, 180])

numerador = (7.0*(150-17) + 7.5*(165-17) + 8.0*(180-17))
denominador = (7.0**2 + 7.5**2 + 8.0**2)
m = numerador / denominador

print(f"\nm manual: {m:.2f}")  # Resultado: ~19.23
# Out:
# Laranjas:
# Coeficiente angular (m) com b=17: 17.52
#
# Toranjas:
# Coeficiente angular (m) com b=17: 31.38
#
# m manual: 19.76
